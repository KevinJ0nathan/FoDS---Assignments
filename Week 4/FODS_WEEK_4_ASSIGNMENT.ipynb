# %% [markdown]
# # FoDS Week 4 Assignment - Kevin Jonathan - 2702342823 - L3BC

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing Datasets which contains 2 tables

# %%
df_movies = pd.read_csv('/content/tmdb_5000_movies.csv')
df_movie_credits = pd.read_csv('/content/tmdb_5000_credits.csv')

# %% [markdown]
# ## 1. Inspect a dataframe with df.head(), df.tail(), df.info(), df.describe().

# %%
# Inspect first 5 rows
df_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Inspect last 5 rows
df_movies.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
# Get info on the DataFrame
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# Summary statistics of numeric columns
df_movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# ## 2. Show Missing Values per Column:

# %%
# Count missing values for each column
df_movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Checking for null in the movie credits csv file
df_movie_credits.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# ## 3. Manipulate how a dataframe displays in Jupyter by modifying Pandas configuration options such as pd.set_option("display.max_rows", n).

# %%
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', 10)
df_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...         ...                                                ...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...                                            ...     ...
# 4801                   http://shanghaicalling.com/  126186
# 4802                                           NaN   25975
#
#                                                keywords  ...    status  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  ...  Released
# ...

# %% [markdown]
# ## 4. Rename columns of a dataframe using the df.rename() function or by accessing the df.columns attribute.

# %%
# Renaming multiple columns
df_movies.rename(columns={'id': 'movie_id', 'budget': 'movie_budget', 'genres':'movie_genres'}, inplace=True)

# %%
# shows the updated named columns
df_movies
# Out:
#       movie_budget                                       movie_genres  \
# 0        237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1        300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...            ...                                                ...
# 4801             0                                                 []
# 4802             0                [{"id": 99, "name": "Documentary"}]
#
#                                           homepage  movie_id  \
# 0                      http://www.avatarmovie.com/     19995
# 1     http://disney.go.com/disneypictures/pirates/       285
# ...                                            ...       ...
# 4801                   http://shanghaicalling.com/    126186
# 4802                                           NaN     25975
#
#                                                keywords  ...    status  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...  ...  Released
# ...

# %% [markdown]
# ## 5. Modify the index name and index values of a dataframe using .set_index(), .reset_index() , df.index.name, .index.

# %%
# Set a column as the index
df_movie_credits.set_index('movie_id', inplace=True)
df_movie_credits
# Out:
#                                              title  \
# movie_id
# 19996                                       Avatar
# 286       Pirates of the Caribbean: At World's End
# ...                                            ...
# 126187                            Shanghai Calling
# 25976                            My Date with Drew
#
#                                                        cast  \
# movie_id
# 19996     [{"cast_id": 242, "character": "Jake Sully", "...
# 286       [{"cast_id": 4, "character": "Captain Jack Spa...
# ...                                                     ...
# 126187    [{"cast_id": 3, "character": "Sam", "credit_id...
# 25976     [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                        crew
# movie_id
# 19996     [{"credit_id": "52fe48009251416c750aca23", "de...
# 286       [{"credit_id": "52fe4232c3a36847f800b579", "de...
# ...                                                     ...
# ...

# %%
# Reset the index to default
df_movie_credits.reset_index(inplace = True)
df_movie_credits
# Out:
#       movie_id                                     title  \
# 0        19996                                    Avatar
# 1          286  Pirates of the Caribbean: At World's End
# ...        ...                                       ...
# 4801    126187                          Shanghai Calling
# 4802     25976                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# ...                                                 ...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# ...                                                 ...
# ...

# %%
# Rename index
df_movie_credits.index.name = 'no.'

# Modify index values by incrementing 1 to each value of index
df_movie_credits.index = df_movie_credits.index.map(lambda x: x + 1)

df_movie_credits
# Out:
#       movie_id                                     title  \
# no.
# 1        19996                                    Avatar
# 2          286  Pirates of the Caribbean: At World's End
# ...        ...                                       ...
# 4802    126187                          Shanghai Calling
# 4803     25976                         My Date with Drew
#
#                                                    cast  \
# no.
# 1     [{"cast_id": 242, "character": "Jake Sully", "...
# 2     [{"cast_id": 4, "character": "Captain Jack Spa...
# ...                                                 ...
# 4802  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4803  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# no.
# 1     [{"credit_id": "52fe48009251416c750aca23", "de...
# 2     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# ...                                                 ...
# ...

# %% [markdown]
# ## 6. Use df.melt() and df.pivot() to reshape dataframes, specifically to make tidy dataframes.

# %%
value_vars = ['homepage', 'overview', 'release_date', 'runtime', 'tagline']
# Melting the DataFrame
df_melted = df_movies.melt(id_vars=['movie_id', 'title'], value_vars=['homepage', 'overview', 'release_date', 'runtime', 'tagline'],
                    var_name='variable', value_name='value')

# Display the melted DataFrame
df_melted.head()
# Out:
#    movie_id                                     title  variable  \
# 0     19995                                    Avatar  homepage
# 1       285  Pirates of the Caribbean: At World's End  homepage
# 2    206647                                   Spectre  homepage
# 3     49026                     The Dark Knight Rises  homepage
# 4     49529                               John Carter  homepage
#
#                                           value
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter

# %%
df_pivoted = df_melted.pivot(index=['movie_id', 'title'], columns='variable', values='value')
df_pivoted = df_pivoted.reset_index()

# Display the pivoted DataFrame
df_pivoted.head()
# Out:
# variable  movie_id            title  \
# 0                5       Four Rooms
# 1               11        Star Wars
# 2               12     Finding Nemo
# 3               13     Forrest Gump
# 4               14  American Beauty
#
# variable                                           homepage  \
# 0                                                       NaN
# 1         http://www.starwars.com/films/star-wars-episod...
# 2                     http://movies.disney.com/finding-nemo
# 3                                                       NaN
# 4                             http://www.dreamworks.com/ab/
#
# variable                                           overview release_date  \
# 0         It's Ted the Bellhop's first night on the job....   1995-12-09
# 1         Princess Leia is captured and held hostage by ...   1977-05-25
# 2         Nemo, an adventurous young clownfish, is unexp...   2003-05-30
# 3         A man with a low IQ has accomplished great thi...   1994-07-06
# ...

# %% [markdown]
# ## 7. Combine dataframes using df.merge() and pd.concat() and know when to use these different methods.

# %%
# Merge two DataFrames based on a common column called 'movie_id'
df_merged = df_movies.merge(df_movie_credits, on='movie_id', how='inner')
df_merged
# Out:
#      movie_budget                                       movie_genres  \
# 0       237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ..            ...                                                ...
# 977         12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 978        220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                          homepage  movie_id  \
# 0                     http://www.avatarmovie.com/     19995
# 1    http://disney.go.com/disneypictures/pirates/       285
# ..                                            ...       ...
# 977                                           NaN       692
# 978                                           NaN      9367
#
#                                               keywords  ... vote_average  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...  ...          7.2
# ...

# %%
# Creating the DataFrame with the dummy data
df_dummy_data = pd.DataFrame({
    'movie_id': [1, 2, 3, 4, 5],
    'title': ['Inception', 'Titanic', 'Avatar', 'The Dark Knight', 'Interstellar'],
    'cast': [
        'Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen Page',
        'Leonardo DiCaprio, Kate Winslet, Billy Zane',
        'Sam Worthington, Zoe Saldana, Sigourney Weaver',
        'Christian Bale, Heath Ledger, Michael Caine',
        'Matthew McConaughey, Anne Hathaway, Jessica Chastain'
    ],
    'crew': [
        'Christopher Nolan (Director), Hans Zimmer (Music)',
        'James Cameron (Director), James Horner (Music)',
        'James Cameron (Director), James Horner (Music)',
        'Christopher Nolan (Director), Hans Zimmer (Music)',
        'Christopher Nolan (Director), Hans Zimmer (Music)'
    ]
})

# Concatenate vertically
df_concat = pd.concat([df_dummy_data, df_movie_credits], axis=0)
df_concat.head(10)
# Out:
#     movie_id                  title  \
# 0          1              Inception
# 1          2                Titanic
# ..       ...                    ...
# 4      49027  The Dark Knight Rises
# 5      49530            John Carter
#
#                                                  cast  \
# 0   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
# 1         Leonardo DiCaprio, Kate Winslet, Billy Zane
# ..                                                ...
# 4   [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 5   [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                  crew
# 0   Christopher Nolan (Director), Hans Zimmer (Music)
# 1      James Cameron (Director), James Horner (Music)
# ..                                                ...
# 4   [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 5   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [10 rows x 4 columns]

# %% [markdown]
# ## 8. Apply functions to a dataframe df.apply() and df.applymap()

# %%
# converts the movie budget into millions
df_movies['movie_budget_millions'] = df_movies['movie_budget'].apply(lambda x: x / 1000000)
df_movies['movie_budget_millions']
# Out:
# 0       237.0
# 1       300.0
#         ...
# 4801      0.0
# 4802      0.0
# Name: movie_budget_millions, Length: 4803, dtype: float64

# %%
#Stripping whitespace from string values
df_cleaned = df_movies.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_cleaned
# Out:
# <ipython-input-121-cf98d16bd997>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cleaned = df_movies.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#       movie_budget                                       movie_genres  \
# 0        237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1        300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...            ...                                                ...
# 4801             0                                                 []
# 4802             0                [{"id": 99, "name": "Documentary"}]
#
#                                           homepage  movie_id  \
# 0                      http://www.avatarmovie.com/     19995
# 1     http://disney.go.com/disneypictures/pirates/       285
# ...                                            ...       ...
# 4801                   http://shanghaicalling.com/    126186
# ...

# %% [markdown]
# ## 9. Find the data which satisfy specific condition using df.query()

# %%
# Filter rows
df_filtered = df_movies.query('vote_count > 10000')
df_filtered
# Out:
#      movie_budget                                       movie_genres  \
# 0       237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 16      220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ..            ...                                                ...
# 287     100000000  [{"id": 18, "name": "Drama"}, {"id": 37, "name...
# 788      58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                      homepage  movie_id  \
# 0                 http://www.avatarmovie.com/     19995
# 16          http://marvel.com/avengers_movie/     24428
# ..                                        ...       ...
# 287                http://unchainedmovie.com/     68718
# 788  http://www.foxmovies.com/movies/deadpool    293660
#
#                                               keywords  ...    status  \
# 0    [{"id": 1463, "name": "culture clash"}, {"id":...  ...  Released
# ...

# %% [markdown]
# ## 10. Perform grouping and aggregating operations using df.groupby() and df.agg(). Perform aggregating methods on grouped or ungrouped objects such as finding the minimum, maximum and sum of values in a dataframe using df.agg().

# %%
# Group by 'status' and count how many movies belong to each status
status_counts = df_movies.groupby('status')['movie_id'].count()

# Display the result
print(status_counts)
# Out:
# status
# Post Production       3
# Released           4795
# Rumored               5
# Name: movie_id, dtype: int64

# %%
# Using aggregate to find min, max, and sum
df_agg = df_movies[['vote_average', 'vote_count']].aggregate(['min', 'max', 'sum'])

# Display the result
print(df_agg)
# Out:
#      vote_average  vote_count
# min           0.0           0
# max          10.0       13752
# sum       29260.7     3315117

# %% [markdown]
# ## 11. Remove or fill missing values in a dataframe with df.dropna() and df.fillna() please practice using different method of filling missing value.

# %%
print(f'Number of rows before cleaning: {len(df_movies)}')
# Drop rows with missing values
df_cleaned = df_movies.dropna()
print(f'Number of rows after cleaning: {len(df_cleaned)}')
# Out:
# Number of rows before cleaning: 4803
# Number of rows after cleaning: 1493

# %%
# Fill missing values with a specific value
df_filled = df_movies['homepage'].fillna("Unavailable")
print(df_filled)
print(f'Amount of null in the dataset: {df_filled.isnull().sum()}')
# Out:
# 0                        http://www.avatarmovie.com/
# 1       http://disney.go.com/disneypictures/pirates/
#                             ...
# 4801                     http://shanghaicalling.com/
# 4802                                     Unavailable
# Name: homepage, Length: 4803, dtype: object
# Amount of null in the dataset: 0

# %%
df_testing_null = df_movies
df_testing_null.loc[1:5, 'spoken_languages'] = pd.NA
df_testing_null['spoken_languages'].head()
# Out:
# 0    [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# Name: spoken_languages, dtype: object

# %%
# Fill missing values using forward fill
df_ffill = df_testing_null.fillna(method='ffill')
df_ffill['spoken_languages'].head()
# Out:
# <ipython-input-86-664714fe9350>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df_testing_null.fillna(method='ffill')
# 0    [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1    [{"iso_639_1": "en", "name": "English"}, {"iso...
# 2    [{"iso_639_1": "en", "name": "English"}, {"iso...
# 3    [{"iso_639_1": "en", "name": "English"}, {"iso...
# 4    [{"iso_639_1": "en", "name": "English"}, {"iso...
# Name: spoken_languages, dtype: object

# %% [markdown]
# # 12. Practice imputing missing values using the SimpleImputer Class in sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
# Initialize the SimpleImputer
# For numerical data, replaces the null value with the mean
imputer_mean = SimpleImputer(strategy='mean')

df_test_dummy_si = df_movies.head(10).copy()
df_test_dummy_si.loc[1,'movie_budget'] = np.nan

df_test_dummy_si['movie_budget'].head()
# Out:
# 0    237000000.0
# 1            NaN
# 2    245000000.0
# 3    250000000.0
# 4    260000000.0
# Name: movie_budget, dtype: float64

# %%
df_test_dummy_si['movie_budget'] = imputer_mean.fit_transform(df_test_dummy_si[['movie_budget']])
df_test_dummy_si['movie_budget'].head()
# Out:
# 0    2.370000e+08
# 1    2.544444e+08
# 2    2.450000e+08
# 3    2.500000e+08
# 4    2.600000e+08
# Name: movie_budget, dtype: float64

# %%
df_test_dummy_si.loc[1,'original_language'] = np.nan
df_test_dummy_si.loc[2,'original_language'] = "fr"
df_test_dummy_si.loc[3,'original_language'] = "cn"
df_test_dummy_si['original_language'].head()
# Out:
# 0     en
# 1    NaN
# 2     fr
# 3     cn
# 4     en
# Name: original_language, dtype: object

# %%
 # For categorical data, replaces the null value with the most common value/string
imputer_freq = SimpleImputer(strategy='most_frequent')
df_test_dummy_si['original_language'] = imputer_freq.fit_transform(df_test_dummy_si[['original_language']]).flatten()
df_test_dummy_si['original_language'].head()
# Out:
# 0    en
# 1    en
# 2    fr
# 3    cn
# 4    en
# Name: original_language, dtype: object

# %% [markdown]
# ## 13. Cleaning Text Data using Regex

# %%
import re
import json

df_movies = pd.read_csv('/content/tmdb_5000_movies.csv')

df_regex_dummy = df_movies.copy()

#Define a regex pattern to extract the names
pattern = r'"name":\s*"((?:[^"\\]|\\.)*)"'

# Function to extract language names using JSON parsing
def extract_language_names(json_str):
  # Check if the input is a string
    if isinstance(json_str, str):
        try:
            # Parse the JSON string
            languages = json.loads(json_str)
            # Extract names from the parsed JSON
            return [lang['name'] for lang in languages]
        except json.JSONDecodeError:
           # Return empty if JSON decoding fails
            return []
    #Return an empty list for non-string inputs
    return []

# Apply the function to the 'spoken_languages' column
df_regex_dummy['language_names'] = df_regex_dummy['spoken_languages'].apply(extract_language_names)

df_regex_dummy['language_names'] = df_regex_dummy['language_names'].apply(lambda x: ', '.join(x) if x else 'No languages found')

# Display the updated DataFrame
print(df_movies[['spoken_languages', 'language_names']])
# Out:
#                                        spoken_languages    language_names
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  English, Español
# 1              [{"iso_639_1": "en", "name": "English"}]           English
# ...                                                 ...               ...
# 4801           [{"iso_639_1": "en", "name": "English"}]           English
# 4802           [{"iso_639_1": "en", "name": "English"}]           English
#
# [4803 rows x 2 columns]
